# %% [markdown]
# <a href="https://colab.research.google.com/github/harshpp707/bioinformatics-rosalind/blob/main/notebooks/Bioinformatics_Module03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## TASK P6.1

# %%
name = input("Enter your name: ")
print("Hello, " + name)
# Out:
# Enter your name: Harsh
# Hello, Harsh

# %% [markdown]
# ## TASK P6.2

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print(a**2 + b**2)
# Out:
# Enter first number: 816
# Enter second number: 906
# 1486692

# %% [markdown]
# ## TASK P7.1

# %%
my_list = ["Hello", "World", "Charles Darwin"]
print(my_list[1])
# Out:
# World

# %% [markdown]
# ## TASK P7.2

# %%
my_list[2] = "Alfred R. Wallace"
print(my_list)
# Out:
# ['Hello', 'World', 'Alfred R. Wallace']

# %% [markdown]
# ## TASK P7.3

# %%
my_list.append("Charles Darwin")
print(my_list)
# Out:
# ['Hello', 'World', 'Alfred R. Wallace', 'Charles Darwin']

# %% [markdown]
# ## TASK P7.4

# %%
my_list.insert(1,"Added New Item")
print(my_list)
# Out:
# ['Hello', 'Added New Item', 'World', 'Alfred R. Wallace', 'Charles Darwin']

# %% [markdown]
# ## TASK P8.1

# %%
print(my_list[2:4])
# Out:
# ['World', 'Alfred R. Wallace']

# %%
my_string = "HelloWorldCharlesDarwinAlfred R. Walace"
print(my_string[0:5], my_string[5:10])
# Out:
# Hello World

# %% [markdown]
# ## TASK P8.2

# %%
print(my_string[33:], my_string[5:10])
# Out:
# Walace World

# %% [markdown]
# ## TASK P8.3

# %%
long_string = "oRhacophorusbY2DSStiM1muHbsNNeMtqrnFhQCkxfP1Fxo3acNdPzpibmwPX6fFgfxjcacanthinuraLYDkQpH3KL37Zy53yumx1APHuUR9PyEezt8G4RUFdrtSjLHkf2wPi8ZQMemvQdVNOarjygaO2RSjiZ7CgxO7KPx4."
a = 1
b = 11
c = 69
d = 79
print(long_string[a:b+1] + ' ' + long_string[c:d+1])
# Out:
# Rhacophorus acanthinura
